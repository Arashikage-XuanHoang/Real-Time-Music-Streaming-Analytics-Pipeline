# %%
import pyspark 
print(pyspark.__version__)
# Out:
# 3.5.0

# %%
from pyspark.sql import SparkSession 

spark = (
    SparkSession
    .builder 
    .appName("Reading parquet data from Minio")
    .master("spark://spark-master:7077")
    .config("spark.cores.max", "4")
    .getOrCreate()
)
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://803615c50843:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://spark-master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Reading parquet data from Minio</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.conf.set("fs.s3a.endpoint", "http://minio:9000")
spark.conf.set("fs.s3a.access.key", "minioadmin")
spark.conf.set("fs.s3a.secret.key", "minioadmin")
spark.conf.set("fs.s3a.path.style.access", "true")
spark.conf.set("fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
spark.conf.set("fs.s3a.aws.credentials.provider",
               "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider")

# %%
df = spark.read \
    .format("parquet") \
    .load("s3a://listen-events/data/")

df.show(30)
# Out:
# +------------------+-------------------+---------+-------------+---------+---------+-----+-------------+--------------------+-----+-----+--------------------+-----------+---------+------+--------+---------+------+-------------+
# |            artist|               song| duration|           ts|sessionId|     auth|level|itemInSession|                city|  zip|state|           userAgent|        lon|      lat|userId|lastName|firstName|gender| registration|
# +------------------+-------------------+---------+-------------+---------+---------+-----+-------------+--------------------+-----+-----+--------------------+-----------+---------+------+--------+---------+------+-------------+
# | Charlelie Couture|Cindy Fait Semblant|234.65752|1773452992532|    16613|Logged In| paid|            2|           Hollywood|33024|   FL|"Mozilla/5.0 (Win...|  -80.24471|26.027261|    64|Castillo|   Robert|     M|1767314082532|
# |       Red Snapper|      Heavy Petting|375.64035|1773452993532|    16508|Logged In| paid|           51|              Sylmar|91342|   CA|Mozilla/5.0 (X11;...|-118.382262|34.326674|    79|   Tyler|  Deandre|     M|1752387176532|
# |Corinne Bailey Rae|Put Your Records On|213.73341|1773453008532|    16626|Logged In| paid|           14|           New Haven|06513|   CT|"Mozilla/5.0 (Win...| -72.870791|41.316686|    49|  Murphy|    Aidan|     M|1725740698532|
# |          Rick Cua|          Crossfire|201.76933|1773453027532|    16628|Logged In| paid|           62|             Roanoke|24017|   VA|Mozilla/5.0 (Wind...| -79.990966|37.297647|    68|   Smith|     Owen|     M|1749780062532|
# |     Los Rodriguez|     Sin Documentos|287.68607|1773453034532|    16691|Logged In| paid|           15|Hot Springs Natio...|71901|   AR|Mozilla/5.0 (Wind...| -92.974072|34.526453|    56|    Wong|   Melvin|     M|1763484666532|
# +------------------+-------------------+---------+-------------+---------+---------+-----+-------------+--------------------+-----+-----+--------------------+-----------+---------+------+--------+---------+------+-------------+
# only showing top 5 rows
