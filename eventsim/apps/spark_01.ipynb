# %%
import pyspark 
print(pyspark.__version__)
# Out:
# 3.5.0

# %%
from pyspark.sql import SparkSession 

spark = (
    SparkSession
    .build
    .appName("MyfirstRepo")
    .master("spark://172.18.0.5:7077")
    .config 
)
